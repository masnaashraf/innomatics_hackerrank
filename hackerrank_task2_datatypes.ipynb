# %% [raw]
# Innomatics Research lab
# Assignment : Solving hacker rank problems in python - Task2-DATA TYPES
# DS_INTERNSHIP_FEB_2023
# submitted by:MASNA

# %% [markdown]
# **Q1:list comprehensions**
# ![image.png](attachment:image.png)

# %%
if __name__ == '__main__':
    x = int(input())
    y = int(input())
    z = int(input())
    n = int(input())
    
    res=[[i,j,k] for i in range(x+1) for j in range(y+1) for k in range(z+1) if (i+j+k)!=n]
    print(res)
# Out:
# 3
# 3
# 5
# 10
# ...

# %% [markdown]
# **Q2-Finding the percentage**
# ![image.png](attachment:image.png)

# %%
if __name__ == '__main__':
    n = int(input())
    student_marks = {}
    for _ in range(n):
        name, *line = input().split()
        scores = list(map(float, line))
        student_marks[name] = scores
    query_name = input()
    
    total_marks = sum(student_marks[query_name])
    average_marks = total_marks/3 
    print("%.2f"%(average_marks))

# %% [markdown]
# **Q3-Find the Runner-Up Score**
# ![image.png](attachment:image.png)

# %%
if __name__ == '__main__':
    n = int(input())
    arr = map(int, input().split())
    
    runner=sorted(set(arr),reverse=True)[1]
    print(runner)

# %% [markdown]
# **Q4-Nested Lists**
# ![image.png](attachment:image.png)

# %%
if __name__ == '__main__':
    students_grade = []
    for i in range(int(input())):
        name = input()
        score = float(input())
        students_grade.append([name, score])
    sorted_scores = sorted(list(set([x[1] for x in students_grade ])))
    second_scores = sorted_scores[1]
    
    std_lowest_grade = []
    for student in students_grade:
        if second_scores == student[1]:
            std_lowest_grade.append(student[0])
    for student in sorted(std_lowest_grade):
        print(student)

# %% [markdown]
# **Q5- Lists**
# ![image.png](attachment:image.png)

# %%
if __name__ == '__main__':
    N = int(input())
    
    list_output=[]
    for i in range(0,N):
        command=input().split()
        if command[0]=='insert':
            list_output.insert(int(command[1]),int(command[2]))
        elif command[0]=="print":
            print(list_output)
        elif command[0]=="remove":
            list_output.remove(int(command[1]))
        elif command[0]=="append":
            list_output.append(int(command[1]))
        elif command[0]=="sort":
            list_output.sort()
        elif command[0]=="pop":
            list_output.pop()
        else:
            list_output.reverse()

# %% [markdown]
# **Q6:Tuples**
# ![image.png](attachment:image.png)

# %%
if __name__ == '__main__':
    n = int(input())
    integer_list = map(int, input().split())
    t=tuple(integer_list)
    print(hash(t))

# %% [markdown]
# **Q7:Introduction to sets**
# ![image.png](attachment:image.png)

# %%
def average(array):
    # your code goes here
    set_val=set(array)
    return (sum(set_val)/len(set_val))

if __name__ == '__main__':
    n = int(input())
    arr = list(map(int, input().split()))
    result = average(arr)
    print(result)

# %% [markdown]
# **Q8-Sets No Idea!**
# ![image.png](attachment:image.png)

# %%
# Enter your code here. Read input from STDIN. Print output to STDOUT
n,m=map(int,input().split())
array=list(map(int,input().split()))
A=set(map(int,input().split()))
B=set(map(int,input().split()))

happiness=0
for i in array:
    if i in A:
        happiness+=1
    elif i in B:
        happiness-=1
print(happiness)

# %% [markdown]
# **Q9-symmetric_difference**
# ![image.png](attachment:image.png)

# %%
# Enter your code here. Read input from STDIN. Print output to STDOUT

M=int(input())
set_M=set(map(int,input().split()))
N=int(input())
set_N=set(map(int,input().split()))

new_Set=sorted(set_M.symmetric_difference(set_N))
for i in new_Set:
    print(i)

# %% [markdown]
# **Q10-set.add()**
#
# ![image.png](attachment:image.png)

# %%
# Enter your code here. Read input from STDIN. Print output to STDOUT
N=int(input())
set_country=set()
for i in range(N):
    stamp_N=input()
    set_country.add(stamp_N)
print(len(set_country))

# %% [markdown]
# **Q11-Set.discard(), remove() & .pop()**
# ![image.png](attachment:image.png)

# %%
n = int(input())
s = set(map(int, input().split()))

operations = int(input())

for x in range(operations):
  oper = input().split()
  if oper[0] == "remove":
    s.remove(int(oper[1]))
  elif oper[0] == "discard":
    s.discard(int(oper[1]))
  else:
    s.pop()
    
print(sum(s))

# %% [markdown]
# **Q12-Set.union() Operation**
# ![image.png](attachment:image.png)

# %%
# Enter your code here. Read input from STDIN. Print output to STDOUT
n=int(input())
set_n=set(map(int,input().split()))
b=int(input())
set_b=set(map(int,input().split()))


setunion=set_n.union(set_b)
print(len(setunion))

# %% [markdown]
# **Q13-Set.intersection() Operation**
# ![image.png](attachment:image.png)

# %%
# Enter your code here. Read input from STDIN. Print output to STDOUT


n=int(input())
set_n=set(map(int,input().split()))
b=int(input())
set_b=set(map(int,input().split()))


setinter=set_n.intersection(set_b)
print(len(setinter))

# %% [markdown]
# **Q14-SET difference**
# ![image.png](attachment:image.png)

# %%
n=int(input())
set_n=set(map(int,input().split()))
b=int(input())
set_b=set(map(int,input().split()))


setdiff=set_n.difference(set_b)
print(len(setdiff))

# %% [markdown]
# **Q15-Symmetric differnece()**
# ![image.png](attachment:image.png)

# %%
n=int(input())
set_n=set(map(int,input().split()))
b=int(input())
set_b=set(map(int,input().split()))


setsemmetric_diff=set_n.symmetric_difference(set_b)
print(len(setsemmetric_diff))

# %% [markdown]
# **q16-Set Mutations**
# ![image.png](attachment:image.png)

# %%
# Enter your code here. Read input from STDIN. Print output to STDOUT

A=int(input())
set_A=set(map(int,input().split()))
N=int(input())

def update_Set(set_A,list_ele,op):
    if op == "update":
        set_A.update(list_ele)
    elif op == "difference_update":
        set_A.difference_update(list_ele)
    elif op == "intersection_update":
        set_A.intersection_update(list_ele)
    else:
        set_A.symmetric_difference_update(list_ele)
    return set_A

for i in range(N):
    op,len_set=input().split()
    list_ele=list(map(int,input().split()))
    set_A=update_Set(set_A,list_ele,op)
print(sum(set_A))

# %% [markdown]
# **Q17-Captian's room**

# %%
# Enter your code here. Read input from STDIN. Print output to STDOUT
k = int(input())
lst = list(map(int,input().split()))

s1 =set() # unique room no list
s2 = set() # room no which appear morethan once

for i in lst:
    if i in s1:
        s2.add(i)
    else:
        s1.add(i)

s = s1.difference(s2)
print(*s)

# %% [markdown]
# **Q18-subset
# ![image.png](attachment:image.png)**

# %%
# Enter your code here. Read input from STDIN. Print output to STDOUT


for i in range(int(input())):
    a = int(input())
    set_a = set(map(int, input().split()))

    b = int(input())
    set_b = set(map(int, input().split()))

    if len(set_a - set_b) == 0:
        print("True")
    else:
        print("False")

# %% [markdown]
# **Q-19-Check Strick Superset
# ![image.png](attachment:image.png)

# %%
# Enter your code here. Read input from STDIN. Print output to STDOUT

def isstrictsuperset(a,b):
    return b.issubset(a) and not(a.issubset(b))

a = set(int(x) for x in input().split(' '))
n = int(input())
res = True

for _ in range(n):
    b = set(int(x) for x in input().split(' '))
    res &= isstrictsuperset(a,b)
    
print(res)
